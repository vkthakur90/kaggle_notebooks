# %% [markdown]
# ## Neural Network Example

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf

# %% [markdown]
# ### Reading dataset

# %%
raw_data = pd.read_csv('heart.csv')

# %%
display(raw_data.head())
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
ax_ = sns.violinplot(x="variable", y="value", data=pd.melt(raw_data))
_ = ax_.set_xticklabels(ax_.get_xticklabels(), rotation = 90)

# %%
features = raw_data.drop('target', axis = 1)
label = raw_data[['target']]

# %% [markdown]
# As we see there are variance of data in different features. We will use batch normalization after every unit

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(10, activation = 'relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(10, activation = 'relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(10, activation = 'relu'),
    tf.keras.layers.Dense(1, activation = 'sigmoid')
])

# %%
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
callbacks = model.fit(x = features.values, y = label.values, epochs = 500)
# Out:
# Epoch 1/500
# 303/303 [==============================] - 0s 1ms/step - loss: 0.7121 - acc: 0.5380
# Epoch 2/500
# 303/303 [==============================] - 0s 42us/step - loss: 0.6625 - acc: 0.5512
# Epoch 3/500
# 303/303 [==============================] - 0s 41us/step - loss: 0.6290 - acc: 0.6139
# Epoch 4/500
# 303/303 [==============================] - 0s 41us/step - loss: 0.5860 - acc: 0.6502
# Epoch 5/500
# 303/303 [==============================] - 0s 41us/step - loss: 0.5662 - acc: 0.7459
# Epoch 6/500
# 303/303 [==============================] - 0s 37us/step - loss: 0.5269 - acc: 0.7789
# Epoch 7/500
# 303/303 [==============================] - 0s 36us/step - loss: 0.5212 - acc: 0.7822
# Epoch 8/500
# 303/303 [==============================] - 0s 45us/step - loss: 0.4942 - acc: 0.7888
# Epoch 9/500
# 303/303 [==============================] - 0s 43us/step - loss: 0.4815 - acc: 0.8020
# Epoch 10/500
# ...
